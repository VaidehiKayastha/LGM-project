# %% [markdown]
# ## Name : Vaidehi Kayastha
# ## Data Science Intern at LetsGrowmore
# ### Task 2: Prediction using Decision Tree Algorithm ( Intermediate level task)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
import scipy as sp
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier,plot_tree
# %matplotlib inline

# %%
Iris = pd.read_csv('Iris.csv')

# %%
# Seeing the first five rows
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Iris = Iris.drop(columns = ['Id'])
Iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
Iris.shape
# Out:
# (150, 5)

# %%
Iris.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
Iris.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
type_species = {'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2}
Iris['Species'].replace(type_species,inplace=True)
numerical_data=Iris.drop('Species',axis=1)
species_data=Iris['Species']

# %%
# Scatter plot
sns.scatterplot(data=numerical_data,x='PetalLengthCm',y='PetalWidthCm',hue=species_data)

# %%
# Scatter plot
sns.scatterplot(data=numerical_data,x='SepalLengthCm',y='SepalWidthCm',hue=species_data)

# %%
#joint plot
sns.jointplot( data=Iris,x="SepalLengthCm", y="SepalWidthCm")

# %%
#joint plot
sns.jointplot( data=Iris,x="PetalLengthCm", y="PetalWidthCm")

# %%
#Density plot
sns.kdeplot(data= Iris, x="SepalLengthCm", y="SepalWidthCm")

# %%
#Density plot
sns.kdeplot(data= Iris, x="PetalLengthCm", y="PetalWidthCm")

# %%
#histogram
Iris['SepalLengthCm'].hist()

# %%
#histogram
Iris['SepalWidthCm'].hist()

# %%
X = Iris.drop('Species',axis=1)
Y = Iris['Species']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25)

# %%
Decision_tree_model=DecisionTreeClassifier(max_depth=4)
Decision_tree_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=4, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
print("Accuracy of Model: ",Decision_tree_model.score(x_train,y_train)*100)
# Out:
# Accuracy of Model:  100.0

# %%
X.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
fig = plt.figure(figsize=(25,20))
plot_tree(Decision_tree_model,feature_names=X.columns,  
                   class_names=list(type_species.keys()),
                   filled=True)
# Out:
# [Text(558.0, 978.48, 'PetalWidthCm <= 0.8\ngini = 0.665\nsamples = 112\nvalue = [41, 35, 36]\nclass = Iris-setosa'),
#  Text(418.5, 761.0400000000001, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]\nclass = Iris-setosa'),
#  Text(697.5, 761.0400000000001, 'PetalWidthCm <= 1.75\ngini = 0.5\nsamples = 71\nvalue = [0, 35, 36]\nclass = Iris-virginica'),
#  Text(279.0, 543.6, 'PetalLengthCm <= 4.95\ngini = 0.105\nsamples = 36\nvalue = [0, 34, 2]\nclass = Iris-versicolor'),
#  Text(139.5, 326.1600000000001, 'gini = 0.0\nsamples = 32\nvalue = [0, 32, 0]\nclass = Iris-versicolor'),
#  Text(418.5, 326.1600000000001, 'PetalWidthCm <= 1.55\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2]\nclass = Iris-versicolor'),
#  Text(279.0, 108.72000000000003, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = Iris-virginica'),
#  Text(558.0, 108.72000000000003, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = Iris-versicolor'),
# ...
